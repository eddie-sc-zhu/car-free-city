# %%
from Model.main import BusModel

model = BusModel(data_path="../datasets/daily_ridership.csv",
                 initial_revenue=0,
                 initial_services=1,
                 initial_convenience=1,
                 fare=2.5,
                 service_coeff=0.1,
                 convenience_effect=0.2,
                 travel_time_factor=0.05)

for i in range(len(model.ridership_data)):
    model.step()

results = model.datacollector.get_model_vars_dataframe()
results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from Model.main import BusModel
#       3 model = BusModel(data_path="../datasets/daily_ridership.csv",
#       4                  initial_revenue=0,
#       5                  initial_services=1,
#    (...)
#       9                  convenience_effect=0.2,
#      10                  travel_time_factor=0.05)
#      12 for i in range(len(model.ridership_data)):
#
# File c:\Users\eddie\Documents\Research\car-free-city\Scripts\Model\main.py:5
#       3 from mesa.time import BaseScheduler
#       4 from mesa.datacollection import DataCollector
# ----> 5 from agent import CommuterAgent
#       7 def calc_avg_travel_time(model):
#       8     total_time = 0
#
# ModuleNotFoundError: No module named 'agent'
